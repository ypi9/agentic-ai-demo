# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Generate a draft of an essay about the {topic}
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    This is a draft essay: {draft}
    Provide critical but constructive feedback for the draft essay. The feedback should 
    address issues such as structure, clarity, strength of argument, and writing style.
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    This is the initial version of the essay: {original_draft}
    This is the constructive feedback or critique on the draft: {reflection}
    Provide a revised essay that addresses the issues mentioned in the feedback.
    It should improve clarity, coherence, argument strength, and overall flow.

    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model = model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In the digital age, social media platforms have become intrinsic to the fabric of societal communication. They facilitate connectivity, foster community engagement, and accelerate the dissemination of information. However, despite these benefits, the rapid proliferation of social media has raised significant concerns regarding privacy, misinformation, and user safety. With these platforms wielding immense influence over public opinion and behavior, the question arises: should social media platforms be regulated by the government? This essay argues in favor of government regulation, focusing on the necessity to protect user data, curb misinformation, and ensure a safer online environment.
#
# The Case for Data Protection:
#
# First and foremost, government regulation is imperative to safeguard user data. Social media platforms, inherently motivated by profit, often exploit user information to enhance advertising revenue. This capitalist drive can jeopardize user privacy and create vulnerabilities to data breaches. By instituting government regulations, users would benefit from standardized data protection laws, ensuring transparency in data usage, storage, and sharing practices. For instance, the European Union’s General Data Protection Regulation (GDPR) serves as a model, providing individuals with greater control over their personal information. Regulation comparable to GDPR could enhance data security and build public trust in social media platforms.
#
# Combating Misinformation:
#
# Furthermore, social media is notoriously fertile ground for the spread of misinformation. False news can be disseminated swiftly and have real-world consequences, from influencing elections to inciting violence. Currently, social media companies self-regulate the content on their platforms, often resulting in inconsistent and inadequate responses to misinformation. Government intervention could standardize content moderation practices, requiring platforms to develop more effective algorithms for identifying and managing false narratives. Though some may argue this infringes on free speech, regulation would be designed to balance the need for truthful information with the right to express diverse viewpoints.
#
# Enhancing User Safety:
#
# In addition to protecting data and mitigating misinformation, regulation is essential for ensuring user safety. Issues such as cyberbullying, harassment, and exposure to harmful content are prevalent, with platforms frequently failing to protect vulnerable user groups adequately. Government standards could enforce stricter measures for addressing and preventing online abuse, making social media environments safer for all users. By holding platforms accountable, regulations would empower users and reinforce social media’s role as a positive force in society.
#
# Addressing Counterarguments:
#
# While there is substantial support for regulation, opponents argue that government involvement could lead to censorship and stifle innovation. However, regulation can be structured to avoid these pitfalls. By collaborating with technology experts, social media companies, and civil society groups, governments can craft nuanced policies that promote safety and transparency without encroaching upon freedom of expression or hindering technological advancements.
#
# Conclusion:
#
# In conclusion, government regulation of social media platforms is not only necessary but inevitable. As these platforms become increasingly influential in shaping societal discourse, the need to protect user data, combat misinformation, and ensure safety becomes more urgent. Though regulation poses challenges, the benefits it offers in creating a more secure and truthful online environment are compelling. Ultimately, governmental oversight can foster a balanced relationship between innovation and the public interest, ensuring social media remains a tool for connection rather than a source of peril.
#
# 🧠 Feedback:
#
# Here’s some targeted, constructive feedback on your draft. I’ve organized it by structure, clarity, argument strength, and writing style—so you can see what’s working well and where you might tighten or deepen your analysis.
#
# 1. Structure
#  • Introduction
#    – Your opening effectively underscores social media’s importance and poses the regulatory question.
#    – Consider ending the intro with a more specific roadmap: briefly list your three main points (data protection, misinformation, user safety) so readers know exactly what to expect.
#  • Body Paragraphs
#    – Each paragraph covers a distinct issue, which is good. To sharpen focus, start each with a clear topic sentence that ties back to your thesis.
#    – You might reorder or group paragraphs (for example, move “counterarguments” right after “misinformation”) to create a more natural flow from problem to solution.
#  • Conclusion
#    – You restate your thesis nicely, but you could strengthen impact by suggesting next steps (e.g., what kind of coalition or legislative process you envision) or pointing to broader implications.
#
# 2. Clarity & Cohesion
#  • Transitions
#    – At times the shift between paragraphs feels abrupt. Add short transitional phrases (e.g., “Building on data concerns,” “Equally important,” “On the other hand”) to guide the reader.
#  • Repetition
#    – Phrases like “social media platforms” and “government regulation” recur very frequently. Vary your wording occasionally—for instance, “online networks,” “public oversight,” or “legislative guardrails.”
#  • Definitions
#    – You reference “harmful content” and “data breaches,” but you could briefly clarify the scope. Are you primarily concerned with personal health data, minors’ privacy, extremist propaganda, deepfakes? Specificity strengthens credibility.
#
# 3. Strength of Argument
#  • Evidence & Examples
#    – You cite GDPR as a positive model—good choice. Enhance each section by adding one more concrete example or statistic:
#      • Data Protection: cite a high-profile breach and its fallout.
#      • Misinformation: mention a study quantifying its spread or real-world effect (e.g., election interference).
#      • User Safety: reference a report on cyberbullying trends or platform reporting shortfalls.
#  • Nuance & Counterarguments
#    – Your counterargument paragraph is on the right track. To deepen it, acknowledge genuine concerns about overreach (e.g., “slippery slope” toward surveillance) and then explain how carefully tailored safeguards (judicial oversight, appeals processes, transparency reports) could mitigate those risks.
#  • Balance of Rights
#    – You note free speech concerns but could add a sentence on how regulation can preserve pluralism (for instance, by requiring platforms to publish clear content-removal criteria and allow user appeals).
#
# 4. Writing Style & Tone
#  • Active vs. Passive Voice
#    – Whenever possible, use active constructions for greater punch:
#      • Change “social media platforms… have become intrinsic” to “We now rely on social media platforms.”
#      • Change “regulation would be designed” to “policymakers can design regulation.”
#  • Sentence Variety
#    – Mix shorter sentences with longer ones to improve rhythm.
#    – Watch out for multi-clause sentences that risk burying your point—break them in two if needed.
#  • Word Choice
#    – Steer clear of generic adjectives like “significant” or “inherent.” Wherever you can, be precise: “Profound,” “systemic,” “involuntary,” etc.
#  • Tone
#    – You strike an appropriately formal tone. If you want to engage readers more, consider a brief anecdote or hypothetical scenario illustrating the stakes (e.g., a parent discovering a child’s personal data sold without consent).
#
# Overall, your essay is well organized and makes a persuasive case for regulation. Sharpening the topic sentences, bolstering each claim with specific evidence, and tightening your prose will elevate it from solid to compelling. Good luck with your revision!
#
# ✍️ Revised:
#
# Title: The Imperative of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In today's digital world, social media platforms have become integral to daily communication, fostering connections, encouraging community interaction, and swiftly spreading information. However, these benefits come with significant concerns about privacy, misinformation, and user safety. Given the substantial influence social media exerts over public opinion and behavior, a critical question emerges: should government regulation oversee these platforms? This essay argues for the necessity of such regulation, focusing on protecting user data, curbing misinformation, and ensuring a secure online environment.
#
# The Case for Data Protection:
#
# To begin with, safeguarding user data is paramount, and government regulation is crucial in this endeavor. Social media platforms, driven by profit, often exploit user information to maximize advertising revenue, putting user privacy at risk and creating opportunities for data breaches. Instituting government regulations would enforce standardized data protection laws, ensuring transparency in data use, storage, and sharing. The European Union's General Data Protection Regulation (GDPR) serves as a commendable model, offering individuals greater control over their information. An analogous regulation could enhance data security and public trust in these platforms. To illustrate, the high-profile data breach at Facebook in 2018, which exposed the personal information of 50 million users, underscores the need for stringent data protection.
#
# Combating Misinformation:
#
# Equally important is the regulation of misinformation, which spreads rapidly on social media and can have severe real-world impacts, such as influencing elections or inciting violence. Currently, social media companies self-regulate content, often resulting in inconsistent and insufficient responses to misinformation. Government intervention could standardize content moderation practices, requiring more effective algorithms to identify and address false narratives. While some argue this might infringe on free speech, a well-designed regulatory framework could balance the need for truthful information with diverse expression rights. For example, a 2018 MIT study highlighted that false news stories spread six times faster on Twitter than factual ones, emphasizing the need for regulatory oversight.
#
# Enhancing User Safety:
#
# Moreover, regulation is vital to ensure user safety. Issues such as cyberbullying, harassment, and exposure to harmful content are pervasive, with platforms inadequately protecting vulnerable groups. Government standards could enforce stricter measures to address and prevent online abuse, creating a safer social media environment for everyone. By holding platforms accountable, these regulations would empower users and reinforce social media's role as a positive influence. A report from the Cyberbullying Research Center showed that 37% of young people experienced cyberbullying, underscoring the urgency of regulatory action.
#
# Addressing Counterarguments:
#
# While there is broad support for regulation, critics fear government involvement could lead to censorship or stifle innovation. However, regulation can be crafted to avoid these outcomes. By collaborating with technology experts, social media companies, and civil society groups, governments can develop nuanced policies that prioritize safety and transparency without encroaching on free expression or hindering technological progress. Genuine concerns about governmental overreach—such as a "slippery slope" toward surveillance—can be mitigated through carefully tailored safeguards like judicial oversight and transparency reports.
#
# Conclusion:
#
# In conclusion, government regulation of social media platforms is not only necessary but inevitable. As these platforms gain influence in shaping societal discourse, the urgency to protect user data, combat misinformation, and ensure safety becomes more pronounced. Although regulation poses challenges, its benefits in fostering a more secure and truthful online environment are compelling. Policymakers can design regulation to preserve pluralism by requiring clear content-removal criteria and allowing user appeals. Ultimately, governmental oversight can balance innovation with public interest, ensuring social media remains a tool for connection rather than a source of peril. Looking ahead, building coalitions between governments, industry leaders, and civil stakeholders could pave the way for effective legislative processes.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In the digital age, social media platforms have become intrinsic to the fabric of societal communication. They facilitate connectivity, foster community engagement, and accelerate the dissemination of information. However, despite these benefits, the rapid proliferation of social media has raised significant concerns regarding privacy, misinformation, and user safety. With these platforms wielding immense influence over public opinion and behavior, the question arises: should social media platforms be regulated by the government? This essay argues in favor of government regulation, focusing on the necessity to protect user data, curb misinformation, and ensure a safer online environment.
#
# The Case for Data Protection:
#
# First and foremost, government regulation is imperative to safeguard user data. Social media platforms, inherently motivated by profit, often exploit user information to enhance advertising revenue. This capitalist drive can jeopardize user privacy and create vulnerabilities to data breaches. By instituting government regulations, users would benefit from standardized data protection laws, ensuring transparency in data usage, storage, and sharing practices. For instance, the European Union’s General Data Protection Regulation (GDPR) serves as a model, providing individuals with greater control over their personal information. Regulation comparable to GDPR could enhance data security and build public trust in social media platforms.
#
# Combating Misinformation:
#
# Furthermore, social media is notoriously fertile ground for the spread of misinformation. False news can be disseminated swiftly and have real-world consequences, from influencing elections to inciting violence. Currently, social media companies self-regulate the content on their platforms, often resulting in inconsistent and inadequate responses to misinformation. Government intervention could standardize content moderation practices, requiring platforms to develop more effective algorithms for identifying and managing false narratives. Though some may argue this infringes on free speech, regulation would be designed to balance the need for truthful information with the right to express diverse viewpoints.
#
# Enhancing User Safety:
#
# In addition to protecting data and mitigating misinformation, regulation is essential for ensuring user safety. Issues such as cyberbullying, harassment, and exposure to harmful content are prevalent, with platforms frequently failing to protect vulnerable user groups adequately. Government standards could enforce stricter measures for addressing and preventing online abuse, making social media environments safer for all users. By holding platforms accountable, regulations would empower users and reinforce social media’s role as a positive force in society.
#
# Addressing Counterarguments:
#
# While there is substantial support for regulation, opponents argue that government involvement could lead to censorship and stifle innovation. However, regulation can be structured to avoid these pitfalls. By collaborating with technology experts, social media companies, and civil society groups, governments can craft nuanced policies that promote safety and transparency without encroaching upon freedom of expression or hindering technological advancements.
#
# Conclusion:
#
# In conclusion, government regulation of social media platforms is not only necessary but inevitable. As these platforms become increasingly influential in shaping societal discourse, the need to protect user data, combat misinformation, and ensure safety becomes more urgent. Though regulation poses challenges, the benefits it offers in creating a more secure and truthful online environment are compelling. Ultimately, governmental oversight can foster a balanced relationship between innovation and the public interest, ensuring social media remains a tool for connection rather than a source of peril.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s some targeted, constructive feedback on your draft. I’ve organized it by structure, clarity, argument strength, and writing style—so you can see what’s working well and where you might tighten or deepen your analysis.
#
# 1. Structure
#  • Introduction
#    – Your opening effectively underscores social media’s importance and poses the regulatory question.
#    – Consider ending the intro with a more specific roadmap: briefly list your three main points (data protection, misinformation, user safety) so readers know exactly what to expect.
#  • Body Paragraphs
#    – Each paragraph covers a distinct issue, which is good. To sharpen focus, start each with a clear topic sentence that ties back to your thesis.
#    – You might reorder or group paragraphs (for example, move “counterarguments” right after “misinformation”) to create a more natural flow from problem to solution.
#  • Conclusion
#    – You restate your thesis nicely, but you could strengthen impact by suggesting next steps (e.g., what kind of coalition or legislative process you envision) or pointing to broader implications.
#
# 2. Clarity & Cohesion
#  • Transitions
#    – At times the shift between paragraphs feels abrupt. Add short transitional phrases (e.g., “Building on data concerns,” “Equally important,” “On the other hand”) to guide the reader.
#  • Repetition
#    – Phrases like “social media platforms” and “government regulation” recur very frequently. Vary your wording occasionally—for instance, “online networks,” “public oversight,” or “legislative guardrails.”
#  • Definitions
#    – You reference “harmful content” and “data breaches,” but you could briefly clarify the scope. Are you primarily concerned with personal health data, minors’ privacy, extremist propaganda, deepfakes? Specificity strengthens credibility.
#
# 3. Strength of Argument
#  • Evidence & Examples
#    – You cite GDPR as a positive model—good choice. Enhance each section by adding one more concrete example or statistic:
#      • Data Protection: cite a high-profile breach and its fallout.
#      • Misinformation: mention a study quantifying its spread or real-world effect (e.g., election interference).
#      • User Safety: reference a report on cyberbullying trends or platform reporting shortfalls.
#  • Nuance & Counterarguments
#    – Your counterargument paragraph is on the right track. To deepen it, acknowledge genuine concerns about overreach (e.g., “slippery slope” toward surveillance) and then explain how carefully tailored safeguards (judicial oversight, appeals processes, transparency reports) could mitigate those risks.
#  • Balance of Rights
#    – You note free speech concerns but could add a sentence on how regulation can preserve pluralism (for instance, by requiring platforms to publish clear content-removal criteria and allow user appeals).
#
# 4. Writing Style & Tone
#  • Active vs. Passive Voice
#    – Whenever possible, use active constructions for greater punch:
#      • Change “social media platforms… have become intrinsic” to “We now rely on social media platforms.”
#      • Change “regulation would be designed” to “policymakers can design regulation.”
#  • Sentence Variety
#    – Mix shorter sentences with longer ones to improve rhythm.
#    – Watch out for multi-clause sentences that risk burying your point—break them in two if needed.
#  • Word Choice
#    – Steer clear of generic adjectives like “significant” or “inherent.” Wherever you can, be precise: “Profound,” “systemic,” “involuntary,” etc.
#  • Tone
#    – You strike an appropriately formal tone. If you want to engage readers more, consider a brief anecdote or hypothetical scenario illustrating the stakes (e.g., a parent discovering a child’s personal data sold without consent).
#
# Overall, your essay is well organized and makes a persuasive case for regulation. Sharpening the topic sentences, bolstering each claim with specific evidence, and tightening your prose will elevate it from solid to compelling. Good luck with your revision!</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Imperative of Government Regulation on Social Media Platforms
#
# Introduction:
#
# In today's digital world, social media platforms have become integral to daily communication, fostering connections, encouraging community interaction, and swiftly spreading information. However, these benefits come with significant concerns about privacy, misinformation, and user safety. Given the substantial influence social media exerts over public opinion and behavior, a critical question emerges: should government regulation oversee these platforms? This essay argues for the necessity of such regulation, focusing on protecting user data, curbing misinformation, and ensuring a secure online environment.
#
# The Case for Data Protection:
#
# To begin with, safeguarding user data is paramount, and government regulation is crucial in this endeavor. Social media platforms, driven by profit, often exploit user information to maximize advertising revenue, putting user privacy at risk and creating opportunities for data breaches. Instituting government regulations would enforce standardized data protection laws, ensuring transparency in data use, storage, and sharing. The European Union's General Data Protection Regulation (GDPR) serves as a commendable model, offering individuals greater control over their information. An analogous regulation could enhance data security and public trust in these platforms. To illustrate, the high-profile data breach at Facebook in 2018, which exposed the personal information of 50 million users, underscores the need for stringent data protection.
#
# Combating Misinformation:
#
# Equally important is the regulation of misinformation, which spreads rapidly on social media and can have severe real-world impacts, such as influencing elections or inciting violence. Currently, social media companies self-regulate content, often resulting in inconsistent and insufficient responses to misinformation. Government intervention could standardize content moderation practices, requiring more effective algorithms to identify and address false narratives. While some argue this might infringe on free speech, a well-designed regulatory framework could balance the need for truthful information with diverse expression rights. For example, a 2018 MIT study highlighted that false news stories spread six times faster on Twitter than factual ones, emphasizing the need for regulatory oversight.
#
# Enhancing User Safety:
#
# Moreover, regulation is vital to ensure user safety. Issues such as cyberbullying, harassment, and exposure to harmful content are pervasive, with platforms inadequately protecting vulnerable groups. Government standards could enforce stricter measures to address and prevent online abuse, creating a safer social media environment for everyone. By holding platforms accountable, these regulations would empower users and reinforce social media's role as a positive influence. A report from the Cyberbullying Research Center showed that 37% of young people experienced cyberbullying, underscoring the urgency of regulatory action.
#
# Addressing Counterarguments:
#
# While there is broad support for regulation, critics fear government involvement could lead to censorship or stifle innovation. However, regulation can be crafted to avoid these outcomes. By collaborating with technology experts, social media companies, and civil society groups, governments can develop nuanced policies that prioritize safety and transparency without encroaching on free expression or hindering technological progress. Genuine concerns about governmental overreach—such as a "slippery slope" toward surveillance—can be mitigated through carefully tailored safeguards like judicial oversight and transparency reports.
#
# Conclusion:
#
# In conclusion, government regulation of social media platforms is not only necessary but inevitable. As these platforms gain influence in shaping societal discourse, the urgency to protect user data, combat misinformation, and ensure safety becomes more pronounced. Although regulation poses challenges, its benefits in fostering a more secure and truthful online environment are compelling. Policymakers can design regulation to preserve pluralism by requiring clear content-removal criteria and allowing user appeals. Ultimately, governmental oversight can balance innovation with public interest, ensuring social media remains a tool for connection rather than a source of peril. Looking ahead, building coalitions between governments, industry leaders, and civil stakeholders could pave the way for effective legislative processes.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
